# %%
import os
if not os.path.exists('thinkdsp.py'):
    # !wget https://github.com/AllenDowney/ThinkDSP/raw/master/code/thinkdsp.py

# %%
import numpy as np
import matplotlib.pyplot as plt
import thinkdsp

from thinkdsp import decorate

# %%
from thinkdsp import Chirp
signal = Chirp(start=220, end=880)
wave1 = signal.make_wave(duration=2)
wave1.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave1.segment(start=0, duration=0.01).plot()
decorate(xlabel="Time (s)")

# %%
wave1.segment(start=0.9, duration=0.01).plot()
decorate(xlabel='Time (s)')

# %%
from thinkdsp import ExpoChirp

signal = ExpoChirp(start=220, end=880)
wave2 = signal.make_wave(duration=2)
wave2.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from thinkdsp import SinSignal
signal = SinSignal(freq=440)

# %%
signal = thinkdsp.Chirp(start=220, end=440)
wave = signal.make_wave(duration=1)
spectrum = wave.make_spectrum()
spectrum.plot(high=700)
decorate(xlabel='Frequency (Hz)')
wave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

# %%
def eye_of_sauron (start, end):
    signal = Chirp(start=start, end=end)
    wave = signal.make_wave(duration=0.5)
    spectrum = wave.make_spectrum()
    
    spectrum.plot(high=1200)
    decorate(xlabel='Frequency (Hz)', ylabel='Amplitude')

# %%
slider1 = widgets.FloatSlider(min=100, max=1000, value=100, step=50)
slider2 = widgets.FloatSlider(min=100, max=1000, value=200, step=50)
interact(eye_of_sauron, start=slider1, end=slider2);
# Out:
# interactive(children=(FloatSlider(value=100.0, description='start', max=1000.0, min=100.0, step=50.0), FloatSl…

# %%
from thinkdsp import CosSignal

# %%
do = Chirp(start=0, end=294.00)
re = Chirp(start=294.33, end=327.03)
mi= Chirp(start=327.03, end=348.83)
fa = Chirp(start=348.83, end=392.44)
sol = Chirp(start=392.44, end=436.04)
la = Chirp(start=436.04, end=490.55)
si = Chirp(start=490.55, end=523.25)
do = Chirp(start=523.25, end=600)

wave = do+re+mi+fa+sol+la+si+do
wave2 = wave.make_wave(duration=10)
wave2.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave2.segment(start=0, duration=10).plot()
decorate(xlabel="Time (s)")

# %%
frequency = Chirp(start=93, end=500)
frequency2 = ExpoChirp (start=600, end=930)
comb = frequency + frequency2
comb = signal.make_wave(duration=3)
comb.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
